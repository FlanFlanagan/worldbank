# %%
import geopandas as gp

# %%
gp.read_file('powerplants/powerplants.shp')
# Out:
# /home/robert/miniconda3/envs/geopandas/lib/python3.8/site-packages/geopandas/array.py:166: ShapelyDeprecationWarning: The array interface is deprecated and will no longer work in Shapely 2.0. Convert the '.coords' to a numpy array instead.
#   return GeometryArray(vectorized.from_shapely(data), crs=crs)
#        capacity_m primary_fu  commission  generation  \
# 0            33.0      Hydro         NaN         NaN
# 1            10.0      Solar         NaN         NaN
# 2            10.0      Solar         NaN         NaN
# 3            66.0      Hydro         NaN         NaN
# 4           100.0      Hydro         NaN         NaN
# ...           ...        ...         ...         ...
# 34931        50.0        Oil         NaN         NaN
# 34932        20.0        Oil         NaN         NaN
# 34933       108.0      Hydro         NaN         NaN
# 34934       920.0       Coal         NaN         NaN
# 34935       750.0      Hydro         NaN         NaN
#
# ...
